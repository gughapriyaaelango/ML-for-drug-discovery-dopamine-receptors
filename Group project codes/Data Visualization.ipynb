# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model

# %%
#Read file
data = pd.read_csv("clean_data.csv")

# %%
#VISUALIZATION

# %%
data.groupby('standard_type').count()
# Out:
#                Unnamed: 0  molecule_chembl_id  canonical_smiles  \
# standard_type
# Activity              128                 128               128
# IC50                 2453                2453              2453
# Inhibition           1258                1258              1258
# Ki                   2190                2190              2190
#
#                standard_value  standard_units    MW  HeavyAtomMolWt  LogP  \
# standard_type
# Activity                  128             128   128             128   128
# IC50                     2453            2453  2453            2453  2453
# Inhibition               1258            1258  1258            1258  1258
# Ki                       2190            2190  2190            2190  2190
#
#                MolMR  NumHDonors  NumHAcceptors  NumAtoms    AR  TPSA    RB  \
# standard_type
# Activity         128         128            128       128   128   128   128
# ...

# %%
data.standard_type.value_counts()
# Out:
# IC50          2453
# Ki            2190
# Inhibition    1258
# Activity       128
# Name: standard_type, dtype: int64

# %%
data.standard_type.value_counts()[:10].plot.bar(figsize=(8,4), ec='black')

plt.title('Top Bioactivity Units', fontsize=14, fontweight='black', pad=15)
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(7.5, 3.5))

sns.scatterplot(x='MW', y='LogP', data=data,  size='standard_value', edgecolor='black', alpha=0.7)

plt.xlabel('MW', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
plt.savefig('plot_MW_vs_LogP.pdf')

# %%
import seaborn as sns
plt.figure(figsize=(7.5, 3.5))

sns.scatterplot(x='standard_value', y='MW', data=data,  size='LogP', edgecolor='black', alpha=0.7)

plt.xlabel('Standard Value', fontsize=14, fontweight='bold')
plt.ylabel('MW', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
plt.savefig('plot_MW_vs_LogP.pdf')
